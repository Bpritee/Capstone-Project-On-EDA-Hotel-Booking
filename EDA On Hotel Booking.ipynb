# %% [markdown]
# # **Project Name**    - EDA On Hotel booking

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
#
# ##### **Name**            - Balabadruni Pritee

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Introduction:
#
# One of the most critical aspects of this industry is managing bookings and reservations. Hoteliers need to be able to predict customer behavior, determine the best times to offer promotions and discounts, and optimize pricing strategies. This is where exploratory data analysis (EDA) can play a crucial role in understanding the factors that drive hotel booking and gives solutions to fix such problems.
#
# Objective :
#
# The objective of this project is to analyze a hotel booking dataset and identify factors that govern hotel bookings.The project aims to answer several key questions,for example such as:
#
# When is the best time of year to book a hotel room? What is the optimal length of stay to get the best daily rate? How likely is a hotel to receive a disproportionately high number of special requests?
#
# Data Cleaning :
#
# * The first step is cleaning the data in analysis process . This involved handling missing data, removing duplicate records, and correcting data types. Some of the cleaning steps performed include:
#
# * Handle the missing data: Missing data is either replaced by the mean, median or mode of the column or by removing the rows with missing values.
# Removing duplicate records: Duplicate records were removed to ensure that each row represented a unique booking. Correct the data types: Some columns in the dataset were incorrectly classified as strings instead of numeric or categorical variables. These were corrected using appropriate data types.
#
# Exploratory Data Analysis :
#
# * The next step in the project was to perform exploratory data analysis (EDA) on the cleaned dataset. The EDA process involved analyzing the data to identify patterns, trends, and relationships. Some of the key findings from the EDA process include:
#
# * Booking patterns: The majority of bookings were made between May and August, and the peak booking month was August. Most bookings were made for one or two nights.
#
# * Customer demographics: Most guests were adults traveling without children. A significant proportion of bookings were made by groups of two adults. Cancellations: Approximately one-third of all bookings were canceled, with resort hotel bookings having a higher cancellation rate than city hotel bookings.
#
# * Special requests: The most common special requests were for a quiet room, followed by requests for a room with a balcony or a view. The resort hotel had a higher proportion of special requests than the city hotel.
# Room types: The most common room type was a double or twin room. The resort hotel had a higher proportion of suites and villas than the city hotel.
# Pricing: The average daily rate for the resort hotel was higher than that of the city hotel. Both hotels had a higher average daily rate in the summer months.
#
# Conclusion:
#
# In conclusion, the EDA process identified several key factors that govern hotel bookings. The data suggests that the best time to book a hotel room is during the summer months, and that the optimal length of stay is one or two nights. Additionally, the data indicates that special requests are a significant factor in hotel bookings, with guests often requesting a quiet room or a room with a view. Finally, the analysis highlights the importance of customer demographics, with adults traveling without children making up the majority of hotel guests.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The project seeks to answer the questions such as:
#
# 1. What are the booking trends for different types of hotels (city vs. resort)?
#
# 2. How do the pricing trends vary for different months and hotel types?
#
# 3. Which booking channels and customer types are most popular for different types of hotels?
#
# 4. What are the most popular room types for different types of hotels? How far in advance do customers typically book their stays?
#
# By answering these questions and providing insights, the project aims to help hotels make data-driven decisions and improve their business operations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# * The objective of this project is to analyze a hotel booking dataset and identify factors that govern hotel bookings and helps to get maximum profit.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from importlib import reload
plt=reload(plt)

# %% [markdown]
# ### Dataset Loading

# %% [markdown]
# https://drive.google.com/file/d/1i6sEtd-MK9Zo7LkTaFefAIhaZJumKrF2/view?usp=drive_link

# %%
# Load Dataset

# Sample Dataset(link) : https://drive.google.com/file/d/1i6sEtd-MK9Zo7LkTaFefAIhaZJumKrF2/view?usp=drive_link
# mounting your drive, so that you can access the files there
# you'll receive a authentication prompt. Complete it.

#drive.mount('/content/drive')
#path = '/content/drive/MyDrive/Hotel_Bookings.csv'
#hotel_booking_data = pd.read_csv(path)

from google.colab import drive
hotel_booking_data = pd.read_csv('Hotel_Bookings.csv')
hotel_booking_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look of Five rows and all the columns
hotel_booking_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
hotel_booking_data.shape # Display the rows and columns count
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotel_booking_data.info() #Display all the information regarding columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(hotel_booking_data[hotel_booking_data.duplicated()]) # Display all the count of duplicate values from the table and duplicate used to get the duplicate values and len will count the duplicate values
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Display how many null values from each column and return the sum
print(hotel_booking_data.isna().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
#sns.heatmap(hotel_booking_data.isnull(),cbar=True)
msno.bar(hotel_booking_data)
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1. The dataset has a total of 119,390 records and 32 columns.
#
# 2. It has information such as the hotel types, booking date, length of stay, number of adults, children, babies, the number of available parking spaces, etc.
#
# 3. By doing some operations I got, that this dataset contains some null values and some duplicated values.
#
# 4. The dataset contains missing values, which are mainly in the agent and company columns and remaining in the country column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_booking_data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
hotel_booking_data.describe(include='all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * hotel: There are two types of hotel i.e. city or resort hotel
#
# * is_canceled: Booking was canceled or not, where
#
#     1=cancelled
#
#     0=not cancelled.
#
# * lead_time: The number of days between the booking date and the arrival date.
#
# * arrival_date_year: The year of arrival date.
#
# * arrival_date_month: The month of arrival date.
#
# * arrival_date_week_number: The week number of arrival date.
#
# * arrival_date_day_of_month: The day of the month of arrival date.
#
# * stays_in_weekend_nights: The number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
#
# * stays_in_week_nights: The number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
#
# * adults: The number of adults in the booking.
#
# * children: The number of children in the booking.babies: The number of babies in the booking.
#
# * meal: The type of meal booked, such as Bed and Breakfast, Half board, Full board, or No meal.
#
# * country: Country of the guest.
#
# * market_segment: The market segment designation, such as Direct, Corporate, or Online TA.
#
# * distribution_channel: The distribution channel used to book the reservation.
#
# * is_repeated_guest: Whether the booking guest is a repeated guest, where 1 indicates that the guest has previously stayed at the hotel and 0 indicates that the guest is a new guest.
#
# * previous_cancellations: The number of previous bookings that were canceled by the guest.
#
# * previous_bookings_not_canceled: The number of previous bookings that were not canceled by the guest.
#
# * reserved_room_type: The code of room type reserved by the guest.
#
# * assigned_room_type: The code for the type of room assigned to the booking.
# booking_changes: The number of changes made to the booking from the moment the booking was entered into the system until the day of arrival.
#
# * deposit_type: The type of deposit made by the guest, such as No Deposit, Refundable, or Non-Refundable.
#
# * agent: The ID of the travel agency that made the booking.
#
# * company: The ID of the company or entity that made the booking.
#
# * days_in_waiting_list: The number of days the booking was on the waiting list before it was confirmed to the customer.
#
# * customer_type: The type of booking, such as Contract, Group, or Transient.
#
# * adr: The average daily rate, which is the total booking amount divided by the total number of nights stayed.
#
# * required_car_parking_spaces: The number of car parking spaces required by the guest.
#
# * total_of_special_requests: The number of special requests made by the guest.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in hotel_booking_data.columns.tolist():
  print("Number of unique in ",i,"is",hotel_booking_data[i].nunique(),".")
# Out:
# Number of unique in  hotel is 2 .
# Number of unique in  is_canceled is 2 .
# Number of unique in  lead_time is 479 .
# Number of unique in  arrival_date_year is 3 .
# Number of unique in  arrival_date_month is 12 .
# Number of unique in  arrival_date_week_number is 53 .
# Number of unique in  arrival_date_day_of_month is 31 .
# Number of unique in  stays_in_weekend_nights is 17 .
# Number of unique in  stays_in_week_nights is 35 .
# Number of unique in  adults is 14 .
# Number of unique in  children is 5 .
# Number of unique in  babies is 5 .
# Number of unique in  meal is 5 .
# Number of unique in  country is 177 .
# Number of unique in  market_segment is 8 .
# Number of unique in  distribution_channel is 5 .
# Number of unique in  is_repeated_guest is 2 .
# Number of unique in  previous_cancellations is 15 .
# Number of unique in  previous_bookings_not_canceled is 73 .
# Number of unique in  reserved_room_type is 10 .
# Number of unique in  assigned_room_type is 12 .
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Getting the dataset shape
hotel_booking_data.shape
# Out:
# (119390, 32)

# %%
# Write your code to make your dataset analysis ready.
# Droping the duplicates value
hotel_booking_data.drop_duplicates(inplace=True)

# %%
# Checking the Size of data after dropping duplicate
hotel_booking_data.shape
# Out:
# (87396, 32)

# %%
# Checking datast data information
hotel_booking_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87392 non-null  float64
#  11  babies                          87396 non-null  int64
# ...

# %%
# Print the blank or null values from dataset
print(hotel_booking_data.isna().sum())
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Filling the null or empty values with zero
hotel_booking_data[['country','agent','company','children']]=hotel_booking_data[['country','agent','company','children']].fillna(0)

# %%
# Checking all null values are eliminated or not
hotel_booking_data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
# After filling null values and printing the shape
hotel_booking_data.shape
# Out:
# (87396, 32)

# %%
# Changing the datatype to integer
hotel_booking_data[['company', 'agent','children']] = hotel_booking_data[['company', 'agent','children']].astype('int64')

# %%
# Also changing the datatype of reservation status date also
hotel_booking_data['reservation_status_date']=pd.to_datetime(hotel_booking_data['reservation_status_date'],format='%Y-%m-%d')

# %%
# Calculating Total Nights Stay in Both the hotels
hotel_booking_data['Total Nights']=hotel_booking_data['stays_in_weekend_nights']+hotel_booking_data['stays_in_week_nights']

# %%
# After changing checking for shape
hotel_booking_data.shape
# Out:
# (87396, 33)

# %%
# Calulating total number of peoples stay in hotels
hotel_booking_data['Total_People']=hotel_booking_data['adults']+hotel_booking_data['children']+hotel_booking_data['babies']

# %%
# Calculating total_revenue
hotel_booking_data['Revenue']=hotel_booking_data['adr']*hotel_booking_data['Total Nights']

# %%
# Finding the maximum revenue for which type of hotel
max_revenue=hotel_booking_data.groupby('hotel')['Revenue'].max()
max_revenue
# Out:
# hotel
# City Hotel      6148.0
# Resort Hotel    7590.0
# Name: Revenue, dtype: float64

# %%
# Calculating maximum weekend nights in both the hotels
max_weekend_night=hotel_booking_data.groupby('hotel')['stays_in_weekend_nights'].max()
max_weekend_night
# Out:
# hotel
# City Hotel      16
# Resort Hotel    19
# Name: stays_in_weekend_nights, dtype: int64

# %%
# Calculating maximum week nights in both the hotels
max_week_night=hotel_booking_data.groupby('hotel')['stays_in_week_nights'].max()
max_week_night
# Out:
# hotel
# City Hotel      41
# Resort Hotel    50
# Name: stays_in_week_nights, dtype: int64

# %%
# Calculating total nights in both the hotels
max_total_night=hotel_booking_data.groupby('hotel')['Total Nights'].max()
max_total_night
# Out:
# hotel
# City Hotel      57
# Resort Hotel    69
# Name: Total Nights, dtype: int64

# %%
# Average daily rates per month for city and resort type hote.
# Grouping hotel and arrival_date_month and finding the average of adr

daily_rates = hotel_booking_data.groupby(["hotel", "arrival_date_month"])["adr"].mean().reset_index(name="avg_daily_rate")

# Sorting the average daily rate in descending order

daily_rates = daily_rates.sort_values(["hotel", "avg_daily_rate"], ascending=False)
print(daily_rates)
# Out:
#            hotel arrival_date_month  avg_daily_rate
# 13  Resort Hotel             August      187.566659
# 17  Resort Hotel               July      156.166914
# 18  Resort Hotel               June      112.340141
# 23  Resort Hotel          September      100.892331
# 20  Resort Hotel                May       80.551101
# 12  Resort Hotel              April       79.283805
# 14  Resort Hotel           December       65.409093
# 22  Resort Hotel            October       63.676313
# 19  Resort Hotel              March       57.569213
# 15  Resort Hotel           February       54.081107
# 16  Resort Hotel            January       49.131584
# 21  Resort Hotel           November       48.823434
# 8     City Hotel                May      127.851240
# 1     City Hotel             August      124.901601
# 6     City Hotel               June      123.836342
# 5     City Hotel               July      120.055385
# 11    City Hotel          September      118.546566
# ...

# %%
#Average daily rate by customer type

rate_by_customer_type=hotel_booking_data.groupby(['hotel','customer_type'])['adr'].mean().reset_index(name='avg_daily_rate')
rate_by_customer_type.sort_values(['hotel','avg_daily_rate'],ascending=False)
# Out:
#           hotel    customer_type  avg_daily_rate
# 6  Resort Hotel        Transient      103.788835
# 4  Resort Hotel         Contract       79.693843
# 7  Resort Hotel  Transient-Party       79.465258
# 5  Resort Hotel            Group       75.463773
# 2    City Hotel        Transient      114.023751
# 0    City Hotel         Contract      107.561149
# 1    City Hotel            Group       93.325793
# 3    City Hotel  Transient-Party       93.131163

# %%
# The total percentage of canceled bookings
canceled_percentage = hotel_booking_data['is_canceled'].mean() * 100
print(canceled_percentage)
# Out:
# 27.489816467572886

# %%
#From which country the most guest came and number
country_most_guest=hotel_booking_data['country'].value_counts()
country_most_guest
# Out:
# PRT    27453
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: country, Length: 178, dtype: int64

# %%
# Getting top five from country most guest came
country_most_guest.head()
# Out:
# PRT    27453
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
# Name: country, dtype: int64

# %%
# From which country the most guest came and number
country_most_guest=hotel_booking_data['country'].value_counts()
country_most_guest.tail()
# Out:
# MMR    1
# BFA    1
# CYM    1
# MLI    1
# KHM    1
# Name: country, dtype: int64

# %%
# Distribution of deposit
disti_of_deposit=hotel_booking_data.groupby('deposit_type')['deposit_type'].count()
disti_of_deposit
# Out:
# deposit_type
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
# Getting maximum adr from hotel
maxi_adr=hotel_booking_data.groupby('hotel')['adr'].max()
maxi_adr
# Out:
# hotel
# City Hotel      5400.0
# Resort Hotel     508.0
# Name: adr, dtype: float64

# %%
# Getting the location of adr of 5400
hotel_booking_data.loc[hotel_booking_data['adr']==5400]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 48515  City Hotel            1         35               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 48515              March                        13                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 48515                        0                     1       2         0
#
#        babies meal country market_segment distribution_channel  \
# 48515       0   BB     PRT  Offline TA/TO                TA/TO
#
#        is_repeated_guest  previous_cancellations  \
# 48515                  0                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 48515                               0                  A                  A
#
#        booking_changes deposit_type  agent  company  days_in_waiting_list  \
# ...

# %%
# Getting cancellation count
hotel_cancell=hotel_booking_data.groupby('hotel')['is_canceled'].count()
hotel_cancell
# Out:
# hotel
# City Hotel      53428
# Resort Hotel    33968
# Name: is_canceled, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations to make dataset analysis ready:
#
# Dropping duplicate values:
# * Firstly, code drops duplicate values which are needed to remove duplicate in the dataframe by using the drop_duplicates().
#
# Filling null values:
# * Then the code fillna() fills null values in the 'company','agent' and 'children' columns with 0. Then also fill 0 in country type hotel in place of Nan
#
# Converting data types:
# * Converting the data type of the 'children', 'company', and 'agent' columns from float to int using the astype() function to perform analysis opertaion and also data type of the 'reservation_status_date' column is converted to datetime using the to_datetime() function.
#
# Adding new columns:
# * 'total_nights' and 'total_people' and 'total_revenue' columns are added into the data frame. The 'total_nights' column is addition of 'stays_in_weekend_nights' and 'stays_in_week_nights' columns. The 'total_people' column is addition of 'adults', 'children', and 'babies' columns.
#
# ## The manipulations for finding insights:
#
# Which type of hotel has highest number of bookings?
#
# * Manipulation : Grouped the data by 'hotel' and use value_counts function.
# * Insights: City type hotel has highest number of bookings.
#
# What is the distribution of croud per month?:
#
# * Manipulation: Grouped the data by 'hotel' and 'arrival_date_month' and count the number of bookings.
# * Insights: August month is the busiest and January month has the least crowd in both the hotels.
#
# What is the relation between the number of bookings and lead time?
#
# * Manipulation: Grouped the data by 'lead_time' and 'hotel' and counts the number of bookings for each combination.
# * Inshghts: As the lead time increases the number of bookings decreases.
#
# What are the most common bookings for room type?
#
# * Manipulation: Grouped the data by 'hotel' and 'reserved_room_type' and count the number of bookings for each combination, then selects the top three most common reserved room types for each hotel.
# * Insights: The most common room type is type 'A' for both the hotels.
#
# What is the daily average rate for both the hotels?
#
# * Manipulation: Grouped the data by 'hotel' and calculate the average daily rate for each hotel.
# * Insights: The city hotel has highest average daily rate.
#
# What is the most preffered hotel type?
#
# * Manipulation: Grouped the data by 'hotel' and calculate the count of occurrence.
# * Insights: The most preferred hotel type is City Hotel.
#
# What is the percentage of cancelled bookings?
#
# * Manipulation: Find the mean of 'is_cancelled' column and multiplied it with 100.
# * Insights: The percentage of cancelled bookings are 27.48.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Chart - 1 - What is the distribution of hotel ?**

# %%
# Get the hotel booking counting

hotel_count=hotel_booking_data['hotel'].value_counts()

# Showing in bar chart

plt.bar(hotel_count.index,hotel_count.values)

# Set the Label

plt.xlabel('Hotel')
plt.ylabel('Number of Booking')
plt.title('Hotel Distribution')
# Out:
# Text(0.5, 1.0, 'Hotel Distribution')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To find the hotel distribution according to booking in the hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The number of bookings by people is high in city hotels compared to resort
# hotels. Above 50,000 peoples are booked in city hotels.
# * In resorts, hotel bookings are around 30,000 above are there and in comparison, the city hotel have the highest bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Growing insights from that chart, have a positive impact on business to improve the growth of the state.

# %% [markdown]
# ## **Chart - 2 - What is the Number of bookings according to Lead Time ?**

# %%
# Get the data of booking according to lead time and plotting a chart

sns.histplot(data=hotel_booking_data , x='lead_time' , kde=True)

# Set the Label

plt.xlabel('Lead Time Distribution')
plt.ylabel('Lead Time')
plt.title('Number of Booking')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get lead time distribution according to the number of bookings done by hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart has a bell-shaped curve with a peak around 0-50 days, indicating that the majority of bookings were made within 50 days of the arrival date.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Growing insights from that chart, have a positive impact on business to improve the growth of the state. For example, the hotel could adjust its pricing strategy to offer more attractive rates to customers, hotel could adjust its staffing and resource allocation based on booking patterns to ensure optimal utilization of resources and a better guest experience.

# %% [markdown]
# ## **Chart - 3 - How many booking is done and how many percentages of bookings got cancelled?**

# %%
# Get the all the booking from the dataset

hotel_booking_data['hotel'].value_counts().plot.pie(explode=[0.02,0.02],autopct='%1.1f%%',shadow=True,figsize=(8,6),fontsize=12)
# Out:
# <Axes: ylabel='hotel'>

# %%
# Get all the bookings which have been canceled by the guests of the hotels

hotel_booking_data['is_canceled'].value_counts().plot.pie(explode=[0.04,0.04],autopct='%1.1f%%',figsize=(8,6),shadow=True,fontsize=12)
# Out:
# <Axes: ylabel='is_canceled'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the total number of bookings and from that booking got canceled by the guest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The booking of city hotel is 61.1% and the resort hotel booking is 38.9%. Where maximum hotel booking by guest is city hotel only.
# * The cancellation of booking of hotel is 27.5% from both the hotels. We can say that guests preferred hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Growing insights from that chart, have a positive impact on business to improve the growth of the state. We can reduce the cancellation rate by taking the feedback from the guest improving according to requirements and taking the business to an up level.

# %% [markdown]
# ## **Chart - 4 - Find the most number of booking done by the agents ?**

# %%
# Get the highest booking according to agent and count the booking in descending order

highest_booking=hotel_booking_data.groupby('agent')['agent'].agg({'count'}).reset_index().rename(columns={'count':'Highest_Booking'}).sort_values(by='Highest_Booking',ascending=False)

# Drop the rows where the agent is equal to zero

highest_booking.drop(highest_booking[highest_booking['agent']==0].index,inplace=True)

# Get the first 10 rows from the highest booking tabel

highest_ten_bookings=highest_booking[:10]

# Print it

highest_ten_bookings
# Out:
#      agent  Highest_Booking
# 9        9            28759
# 174    240            13028
# 14      14             3349
# 7        7             3300
# 183    250             2779
# 175    241             1644
# 27      28             1502
# 8        8             1383
# 1        1             1232
# 6        6             1117

# %%
# Set the figure size

plt.figure(figsize=(18,8))

# Ploting the bar plot number of booking by agents

sns.barplot(x=highest_ten_bookings['agent'],y=highest_ten_bookings['Highest_Booking'],order=highest_ten_bookings['agent'])

# Set the label

plt.xlabel('Agents Nos')
plt.ylabel('Number of Bookings')
plt.title('Most Number of Bookings by Agents')
# Out:
# Text(0.5, 1.0, 'Most Number of Bookings by Agents')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the information regarding booking done by agents.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * According to chart the agent 9 has been done with more the 25,000 bookings in hotels and the agents are getting an improvement in hotel booking some agents have done with fewer bookings also.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, We can say to our agents to improve in number of bookings so that the hotels get promoted and get bookings regularly. Gaining the insights from that chart, its positive impact on business to improve the growth of states.

# %% [markdown]
# ## **Chart - 5 - Find the repeated guest in hotels and what is the percentage rate ?**

# %%
# Get the repeated guest percentage of hotels and set the font size, show the percentage and plot the chart

hotel_booking_data['is_repeated_guest'].value_counts().plot.pie(explode=(0.05,0.05),shadow=False,autopct='%1.1f%%',fontsize=15,figsize=(8,6))

# Set the title

plt.title('Percentage (%) Of Repeated Guest')
# Out:
# Text(0.5, 1.0, 'Percentage (%) Of Repeated Guest')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the information regarding repeated guests to hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From the chart we can say 96.1% of guests are repeating to a hotel stay and we can say it's a good rate of repeating the customers to stay in hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * According to this we can say the good rate of repeating guest are there and it's very useful for business impact also. And if in future we see it's getting decreasing we can promote the hotel.

# %% [markdown]
# ## **Chart - 6 - Find is the distribution percentage of customer type  ?**

# %%
# Get the customer type and set font size, percentage and plot the chart

hotel_booking_data['customer_type'].value_counts().plot.pie(explode=[0.04]*4,shadow=False,autopct='%1.1f%%',figsize=(8,6),fontsize=15,labels=None)

# Set into the order

labels=hotel_booking_data['customer_type'].value_counts().index.tolist()

# Set the label

plt.title('Percentage (%) Distribution of Customer Type')

# Set the label for customer type

plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To find the distribution percentage of customer type in both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Contract
#
# when the booking has an allotment or other type of contract associated to it
#
# 2. Group
#
# when the booking is associated to a group
#
# 3. Transient
#
# when the booking is not part of a group or contract, and is not associated to other transient booking
#
# 4. Transient-party
#
# when the booking is transient, but is associated to at least other transient bookingAnswer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Transient customer type is more which is 82.4 %. percentage of Booking associated by the Group is very low.

# %% [markdown]
# ## **Chart - 7 - Find the adr across each month ?**

# %%
# Get the arrival date, hotel and mean of adr

booking_of_month=hotel_booking_data.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

# Set the months

months=['January','February','March','April','May','June','July','August','September','October','November','December']

# Set the categorical in order with months and adr

booking_of_month['arrival_date_month']=pd.Categorical(booking_of_month['arrival_date_month'],categories=months,ordered=True)

# sort the months

booking_of_month=booking_of_month.sort_values('arrival_date_month')

# Print it

booking_of_month
# Out:
#    arrival_date_month         hotel         adr
# 8             January    City Hotel   85.092612
# 9             January  Resort Hotel   49.131584
# 6            February    City Hotel   88.945304
# 7            February  Resort Hotel   54.081107
# 15              March  Resort Hotel   57.569213
# 14              March    City Hotel   94.763375
# 0               April    City Hotel  117.156250
# 1               April  Resort Hotel   79.283805
# 17                May  Resort Hotel   80.551101
# 16                May    City Hotel  127.851240
# 13               June  Resort Hotel  112.340141
# 12               June    City Hotel  123.836342
# 11               July  Resort Hotel  156.166914
# 10               July    City Hotel  120.055385
# 3              August  Resort Hotel  187.566659
# 2              August    City Hotel  124.901601
# 22          September    City Hotel  118.546566
# 23          September  Resort Hotel  100.892331
# 20            October    City Hotel  107.304166
# ...

# %%
# Set Figure size

plt.figure(figsize=(15,7))

# Plot a line chart with the months and adr of hotels

sns.lineplot(x=booking_of_month['arrival_date_month'],y=booking_of_month['adr'],hue=booking_of_month['hotel'])

# Set the label

plt.title('ADR Across Each Month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To find the adr across each month with the help of a line chart of both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * For Resrot hotel is ADR is high in the months June, July, August as compared to City Hotels. May be Customers/People wants to spend their Summer vaccation in Resorts Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The best time for guests to visit resorts or City hotels is January, February, March, April, October, November, and December as the average daily rate in this month is very low.

# %% [markdown]
# ## **Chart - 8 - Find the adr across distribution channel ?**

# %%
# Get the distribution channel of hotels and mean of adr then rest the index

distribution_channel=hotel_booking_data.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# Set the figure size

plt.figure(figsize=(12,9))

# Plot the chart between adr and distribution channel according to hotel

sns.barplot(x='distribution_channel',y='adr',data=distribution_channel,hue='hotel')

# Set the label

plt.title('ADR Across Distribution Channel')
# Out:
# Text(0.5, 1.0, 'ADR Across Distribution Channel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To find the adr across distribution channels in both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Corporate- These are corporate hotel booing companies that make bookings possible.
# * GDS-A GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# * Direct- means that bookings are directly made with the respective hotels
# TA/TO- means that booings are made through travel agents or travel operators.
# * Undefined- Bookings are undefined. may be customers made their bookings on arrival.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * From the plot is clear that
# 'Direct' and 'TA/TO' have almost equally contributed in adr in both types of hotels i.e. 'City Hotel' and 'Resort Hotel'.
# GDS has highly contributed in adr in 'City Hotel' type.
# GDS needs to increase Resort Hotel bookings.

# %% [markdown]
# ##**Chart - 9 - Find the cancellation Rate vs distribution channel of both the hotels ?**

# %%
# Get the data which hotels got canceled

cancelled=hotel_booking_data[hotel_booking_data['is_canceled']==1]

# Get the data distribution channel, hotel and reset the index

cancelled_df=cancelled.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'Counts'})

# Set the figure size

plt.figure(figsize=(12,8))

# Plot the chart distribution channel and counting the canceled hotels

sns.barplot(x='distribution_channel',y='Counts',hue='hotel',data=cancelled_df)

# Set the labels

plt.xlabel('Distribution Channel')
plt.ylabel('Count')
plt.title('Cancellation Rate VS Distribution Channel')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate VS Distribution Channel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the cancellation Rate against the distribution channel of both the hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * In "TA/TO", City hotels has the high cancellation rate compared to resort hotels.
# * In "direct" both the hotels has almost same cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes its get a positive impact on business according to the cancellation rate we can say how business is going.

# %% [markdown]
# ##**Chart - 10 - Find the cancellation Rate according to the market segments of both hotels ?**

# %%
# Get the data which hotels got canceled

market_segment=hotel_booking_data[hotel_booking_data['is_canceled']==1]

# Get the data of market segment, hotels and count the canceled hotels then reset the index

market_segment=market_segment.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'Counts'})

# Print it

market_segment
# Out:
#    market_segment         hotel  Counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      57
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     264
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     890
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1261
# 10  Offline TA/TO  Resort Hotel     802
# 11      Online TA    City Hotel   12618
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
# Set the figure size

plt.figure(figsize=(12,8))

# plot the chart in between market segment and cancellation hotels

sns.barplot(x='market_segment',y='Counts',hue='hotel',data=market_segment)

# Set the label

plt.xlabel('Market Segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs Market Segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs Market Segment')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the information regarding market segment according to the cancellation of hotels by the guest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * 'Online T/A' has the highest cancellation in both types of cities.
# * To reduce the booking cancellations hotels need to set the refundable/ no refundable and deposit policies policies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, its get a positive impact on business according to the cancellation rate we can check the market segments according to that we can change the market segments.

# %% [markdown]
# ##**Chart - 11 - Find the adr across the market segment ?**

# %%
# Get the data of market segments of hotels that got canceled and the mean of adr

adrmar=hotel_booking_data.groupby(['market_segment','hotel','is_canceled'])['adr'].mean().reset_index()

# Set the figure size

plt.figure(figsize=(12,8))

# Plot the chart of adr across market segment

sns.barplot(x='market_segment',y='adr',hue='hotel',data=adrmar.sort_values(by='adr',ascending=False))

# Set the label

plt.title("Adr Across Market Segment")
# Out:
# Text(0.5, 1.0, 'Adr Across Market Segment')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the information of adr across the market segment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * 'Direct' and 'Online TA' are contributing the most in both types of hotels.
# * Aviation segment should focus on increasing the bookings of 'City Hotel'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, its get a positive impact on business according to the adr we can check the market segments according to that we can change the market segments or can be improved.

# %% [markdown]
# ## **Chart - 12 - What is the Optimal stay length in both types of hotels ?**

# %%
# Get the total nights stay by the guest of the hotels and reset the index

stay=hotel_booking_data.groupby(['Total Nights','hotel']).agg('count').reset_index()

# Get the last 3 columns

stay=stay.iloc[ : , :3]

# Rename the is canceled column in to number of stay

stay=stay.rename(columns={'is_canceled':'Number of stays'})

# Print it

stay
# Out:
#     Total Nights         hotel  Number of stays
# 0              0    City Hotel              288
# 1              0  Resort Hotel              363
# 2              1    City Hotel            10284
# 3              1  Resort Hotel             6900
# 4              2    City Hotel            10824
# ..           ...           ...              ...
# 71            49    City Hotel                1
# 72            56  Resort Hotel                2
# 73            57    City Hotel                1
# 74            60  Resort Hotel                1
# 75            69  Resort Hotel                1
#
# [76 rows x 3 columns]

# %%
# Set the figure size

plt.figure(figsize=(12,8))

# Plot the chart of total nights where got stay in hotels

sns.barplot(x='Total Nights',y='Number of stays',hue='hotel',data=stay)

# Set the labels

plt.title('Stay Length In Both The Hotel Type')
plt.xlabel('Total Nigths (Days)')
plt.ylabel('Counts Of Stay')
# Out:
# Text(0, 0.5, 'Counts Of Stay')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the Optimal stay length in both types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Optimal stay in both types of hotels is less than 7 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, its get a positive impact on business according to the optimal stay. As optimal stay increases the growth of that hotel increases.

# %% [markdown]
# ## **Chart - 13 - What is the relation between stay and adr in both types of hotels ?**

# %%
# Get the total nights of the hotels and adr

adr_vs_stay=hotel_booking_data.groupby(['Total Nights','adr','hotel']).agg('count').reset_index()

# Get the last 3 columns

adr_vs_stay=adr_vs_stay.iloc[ : , :3]

# Rename canceled to number of stay

adr_vs_stay=adr_vs_stay.rename(columns={'is_canceled':'Number of stay'})

# Set the limit upto 18000 data

adr_vs_stay=adr_vs_stay[:18000]

# Print it

adr_vs_stay
# Out:
#        Total Nights     adr         hotel
# 0                 0    0.00    City Hotel
# 1                 0    0.00  Resort Hotel
# 2                 1    0.00    City Hotel
# 3                 1    0.00  Resort Hotel
# 4                 1    1.00    City Hotel
# ...             ...     ...           ...
# 17995             7  210.86  Resort Hotel
# 17996             7  211.00  Resort Hotel
# 17997             7  211.03  Resort Hotel
# 17998             7  211.16  Resort Hotel
# 17999             7  211.20  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
# Plot the figure

plt.figure(figsize=(12,8))

# Plot the chart of total stay and adr

sns.lineplot(x='Total Nights',y='adr',data=adr_vs_stay)

# Set the label

plt.title('Relation Between Total Stay and Adr')
# Out:
# Text(0.5, 1.0, 'Relation Between Total Stay and Adr')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * To get the relation between stay and adr in both types of hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As the total stay increases the adr also increases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, Its give a positive impact on business.

# %% [markdown]
# ## **Chart - 14 - Correlation Heatmap**

# %%
# Set the figure size

plt.figure(figsize=(18,10))

# Correlation Heatmap visualization code

sns.heatmap(hotel_booking_data.corr(),annot=True)

# Set the title

plt.title('Co-relation of all the columns')
# Out:
# <ipython-input-128-795a2f993c80>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(hotel_booking_data.corr(),annot=True)
# Text(0.5, 1.0, 'Co-relation of all the columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * Correlation Heatmap visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * is_canceled and same_room_alloted_or_not are negatively correlated. That means the customer is unlikely to cancel his bookings if he doesn't get the same room as per reserved room. We have visualized it above.
# *  lead_time and total_stay are positively correlated. That means more the stay of customers more will be the lead time.
# * adults, children, and babies are correlated to each other. That means more people will be adr.
# *  is_repeated guest and previous bookings not canceled have a strong correlation. may be repeated guests are not more likely to cancel their bookings.

# %% [markdown]
# ## **Chart - 15 - Pair Plot**

# %%
# Select a subset of columns to plot
columns_to_plot = ["is_canceled", "lead_time", "stays_in_weekend_nights", "stays_in_week_nights", "adults"]

# Create the pair plot
sns.pairplot(data=hotel_booking_data,vars=columns_to_plot, hue="is_canceled")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * The pair plot as a type of chart because it allows us to visualize the relationships between multiple variables in a dataset. By using different colors to differentiate between the is_canceled variable, we can see how it relates to the other variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * This can help us identify patterns and correlations that may be useful for further analysis or modeling. For example, we may notice that there is a strong positive correlation between lead_time and the likelihood of cancellation, which could be useful in predicting cancellations in the future.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# According to the exploratory data analysis of hotel bookings, there are many suggestions that can be done to achieve business objectives.
#
# Here are some of them:
#
# * Understanding the busiest booking months. The analysis shows that June, July, and August are the busiest months for hotel bookings. So, the hotel can increase its prices during these months, offer special packages and deals, and prepare accordingly to accommodate more guests during this time, and while off-peak season hotel mananger have to give more discounts and offers in such a way that customers will atract towards the hotels.
#
# * Analyzing the booking channels and market segments. The data shows that the majority of bookings are made through online travel agents and direct booking channels.The hotel should focus on improving its online presence and making it easy for customers to book directly from their website.
#
# * Managing lead times: The analysis shows that longer lead times result in lower rates, and vice versa. The hotel can consider offering discounts for guests who book well in advance to incentivize early bookings, and also use less pricing to adjust rates based on demand.
#
# * Enhancing customer experience: The data suggests that guests who book a higher room type tend to give higher ratings. Hence, the hotel can consider upgrading guests to higher room types based on availability, and focus on delivering a high-quality experience to guests during their stay.
#
# * Retaining repeat customers: The analysis shows that repeat guests make up a very small portion of bookings. Hence, the hotel can consider implementing loyalty programs, offering discounts to repeat guests, and focusing on delivering a personalized experience to encourage repeat bookings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# * 27.5 %of bookings were got canceled out of all the bookings.
# * The percentage of 0 changes made in the booking was more than 82 %. Percentage of Single changes made was about 10%.
# * Most of the customers (91.6%) do not require car parking spaces.
# * 79.1 % bookings were made through TA/TO (travel agents/Tour operators).
# * BB( Bed & Breakfast) is the most preferred type of meal by the guests.
# * Most of the bookings for City hotels and Resort hotel were happened in 2016.
# * Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
# * Booking cancellation rate is high for City hotels which almost 30 %.
# * Average lead time for resort hotel is high.
# * Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
# * Resort hotels have the most repeated guests.
# * Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
# * Almost 19 % people did not cancel their bookings even after not getting the same room that they reserved while booking a hotel. Only 2.5 % of people canceled the booking.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
